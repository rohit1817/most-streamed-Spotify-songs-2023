# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit1817/most-streamed-Spotify-songs-2023/blob/main/spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/dataset.csv', encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# Check for missing values

# %%
nan_values = df.isna()
any_missing_values = nan_values.any().any()
any_missing_values_in_column = nan_values.any()
missing_value_count = df.isnull().sum()
for column, has_missing in any_missing_values_in_column.items():
    if has_missing:
        count = missing_value_count[column]
        print(f" Column '{column}' has {count} missing values.")

print("\nMissing Values in the Entire DataFrame?")
print(any_missing_values)

print("\nMissing Values in Each Column?")
print(any_missing_values_in_column)

print("\nMissing Value Counts in Each Column:")
print(missing_value_count)
# Out:
#  Column 'in_shazam_charts' has 50 missing values.
#  Column 'key' has 95 missing values.
#
# Missing Values in the Entire DataFrame?
# True
#
# Missing Values in Each Column?
# track_name              False
# artist(s)_name          False
# artist_count            False
# released_year           False
# released_month          False
# released_day            False
# in_spotify_playlists    False
# in_spotify_charts       False
# streams                 False
# in_apple_playlists      False
# in_apple_charts         False
# in_deezer_playlists     False
# in_deezer_charts        False
# in_shazam_charts         True
# bpm                     False
# key                      True
# mode                    False
# danceability_%          False
# valence_%               False
# energy_%                False
# acousticness_%          False
# instrumentalness_%      False
# liveness_%              False
# speechiness_%           False
# dtype: bool
#
# Missing Value Counts in Each Column:
# ...

# %%
#Dropping rows with missing values
df.dropna(inplace=True)

# %%
#Changing the streams coloumn to numeric
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
df['in_deezer_playlists'] = pd.to_numeric(df['in_deezer_playlists'], errors='coerce')
df['in_shazam_charts'] = pd.to_numeric(df['in_shazam_charts'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            817 non-null    object
#  1   artist(s)_name        817 non-null    object
#  2   artist_count          817 non-null    int64
#  3   released_year         817 non-null    int64
#  4   released_month        817 non-null    int64
#  5   released_day          817 non-null    int64
#  6   in_spotify_playlists  817 non-null    int64
#  7   in_spotify_charts     817 non-null    int64
#  8   streams               816 non-null    float64
#  9   in_apple_playlists    817 non-null    int64
#  10  in_apple_charts       817 non-null    int64
#  11  in_deezer_playlists   752 non-null    float64
#  12  in_deezer_charts      817 non-null    int64
#  13  in_shazam_charts      813 non-null    float64
#  14  bpm                   817 non-null    int64
# ...

# %%
#Renaming some columns for better understanding

column_name_mapping = {
    'artist(s)_name': 'artist_name',
    'danceability_%': 'danceability',
    'valence_%': 'valence',
    'energy_%': 'energy',
    'acousticness_%': 'acousticness',
    'instrumentalness_%': 'instrumentalness',
    'liveness_%': 'liveness',
    'speechiness_%': 'speechiness'
}

# Use the rename method to update column names
df.rename(columns=column_name_mapping, inplace=True)

# Check the updated column names
print(df.columns)
# Out:
# Index(['track_name', 'artist_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability', 'valence', 'energy', 'acousticness',
#        'instrumentalness', 'liveness', 'speechiness'],
#       dtype='object')

# %%
df.head()
# Out:
#                             track_name       artist_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts      streams  in_apple_playlists  ...  bpm  key   mode  \
# ...

# %%
#Replacing the ',' with 'and' in the case of multiple artist names and removing non english characters

df['artist_name'] = df['artist_name'].str.replace(',', ' and')

#df['track_name'] = df['track_name'].str.replace(r'\(.*\)', '', regex=True)
df['track_name'] = df['track_name'].str.replace('[^a-zA-Z\s]', '', regex=True)

# %%
df.head()
# Out:
#                       track_name          artist_name  artist_count  \
# 0  Seven feat Latto Explicit Ver  Latto and Jung Kook             2
# 1                           LALA          Myke Towers             1
# 2                        vampire       Olivia Rodrigo             1
# 3                   Cruel Summer         Taylor Swift             1
# 4                 WHERE SHE GOES            Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts      streams  in_apple_playlists  ...  bpm  key   mode  \
# ...

# %%
long_track_names = df[df['track_name'].str.len() >= 50]['track_name']

# Display the resulting track names
for track_name in long_track_names:
    print(track_name)
# Out:
# Popular with Playboi Carti  Madonna  The Idol Vol  Music from the HBO Original Series
# Until I Found You with Em Beihold  Em Beihold Version
# Annihilate SpiderMan Across the SpiderVerse Metro Boomin  Swae Lee Lil Wayne Offset
# Self Love SpiderMan Across the SpiderVerse Metro Boomin  Coi Leray
# All The Way Live SpiderMan Across the SpiderVerse Metro Boomin  Future Lil Uzi Vert
# Superhero Heroes  Villains with Future  Chris Brown
# Link Up Metro Boomin  Don Toliver Wizkid feat BEAM  Toian  SpiderVerse Remix SpiderMan Across the SpiderVerse
# Enemy with JID  from the series Arcane League of Legends
# Lift Me Up  From Black Panther Wakanda Forever  Music From and Inspired By
# The Christmas Song Merry Christmas To You  Remastered
# Wonderful Christmastime  Edited Version  Remastered
# Its Beginning to Look a Lot Like Christmas with Mitchell Ayres  His Orchestra
# You Make It Feel Like Christmas feat Blake Shelton
# Cay La Noche feat Cruz Cafun Abhir Hathi Bejo EL IMA
# ...

# %%
long_artist_names = df[df['artist_name'].str.len() >= 50]['artist_name']

# Display the resulting artist names
for artist_name in long_artist_names:
    print(artist_name)
# Out:
# Sachin-Jigar and Shadab Faridi and Altamash Faridi and Amitabh Bhattacharya and Varun Jain
# Veigh and Bvga Beatz and Supernova Ent and Prod Malax
# Swae Lee and Lil Wayne and Offset and Metro Boomin
# Kodak Black and NLE Choppa and Muni Long and JVKE and Jimin
# Natanael Cano and Gabito Ballesteros and Peso Pluma
# Arijit Singh and Sachin-Jigar and Amitabha Bhattacharya
# WizKid and Toian and Metro Boomin and Don Toliver and Beam
# sped up nightcore and ARIZONATEARS and Lil Uzi Vert
# Duki and NICKI NICOLE and Cris Mj and Standly and Stars Music Chile
# Imagine Dragons and League of Legends and JID and Arcane
# Arijit Singh and Vishal Dadlani and Sukriti Kakar and Vishal-Shekhar and Shekhar Ravjiani and Kumaar
# Vishal-Shekhar and Shilpa Rao and Caralisa Monteiro and Kumaar and Vishal Dadlani and Shekhar Ravjiani
# John Lennon and The Harlem Community Choir and The Plastic Ono Band and Yoko Ono
# Bing Crosby and John Scott Trotter & His Orchestra and Ken Darby Singers
# ...

# %%
df['artist_name'] = df['artist_name'].str.slice(0, 49)
df['track_name'] = df['track_name'].str.slice(0, 49)

# %%
df.head()
# Out:
#                       track_name          artist_name  artist_count  \
# 0  Seven feat Latto Explicit Ver  Latto and Jung Kook             2
# 1                           LALA          Myke Towers             1
# 2                        vampire       Olivia Rodrigo             1
# 3                   Cruel Summer         Taylor Swift             1
# 4                 WHERE SHE GOES            Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts      streams  in_apple_playlists  ...  bpm  key   mode  \
# ...

# %%
df.to_csv('new_dataset.csv', index=False)
